# %% [markdown]
# ### 0. Importer les bibliothèques nécessaires

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ---
# ---
# ## 1. Data Sourcing

# %%
apps = pd.read_csv("dataSets/googleplaystore.csv")
apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %% [markdown]
# ### Informations générales

# %%
apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
print(apps.ndim)
print(apps.size)
print(apps.shape)
# Out:
# 2
# 140933
# (10841, 13)

# %%
ratings = apps.iloc[:, 2:4].values
ratings
# Out:
# array([[4.1, '159'],
#        [3.9, '967'],
#        [4.7, '87510'],
#        ...,
#        [nan, '3'],
#        [4.5, '114'],
#        [4.5, '398307']], dtype=object)

# %%
ratings.shape
# Out:
# (10841, 2)

# %% [markdown]
# ---
# ## 2. Data Cleaning

# %% [markdown]
# On supprime les 3 dernières colonnes, puisque on n'en aura pas besoin.

# %%
apps.drop('Last Updated', axis = 1, inplace = True)
apps.drop('Current Ver', axis = 1, inplace = True)
apps.drop('Android Ver', axis = 1, inplace = True)

# %%
apps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres
# 0               Art & Design
# 1  Art & Design;Pretend Play
# 2               Art & Design
# 3               Art & Design
# 4    Art & Design;Creativity

# %% [markdown]
# ### Valeurs Uniques du dataset

# %%
def unique_col_values(df):
    for column in df:
        print("{} | {} | {}".format(
            df[column].name, len(df[column].unique()), df[column].dtype))

unique_col_values(apps)
# Out:
# App | 9660 | object
# Category | 34 | object
# Rating | 41 | float64
# Reviews | 6002 | object
# Size | 462 | object
# Installs | 22 | object
# Type | 4 | object
# Price | 93 | object
# Content Rating | 7 | object
# Genres | 120 | object

# %%
print("Nombre d'applications dans le dataset : " , len(apps))
apps.sample(7)
# Out:
# Nombre d'applications dans le dataset :  10841
#                                                      App            Category  \
# 10198                            Swift for Facebook Lite              SOCIAL
# 191                               Snag - Jobs Hiring Now            BUSINESS
# 1393                               10 Best Foods for You  HEALTH_AND_FITNESS
# 524    Hide App, Private Dating, Safe Chat - PrivacyH...              DATING
# 3257     Files Go by Google: Free up space on your phone               TOOLS
# 1426                              Binaural Beats Therapy  HEALTH_AND_FITNESS
# 4691                           San Andreas: Gang Crime V                GAME
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10198     4.3    9562                5.8M     500,000+  Free     0
# 191       4.3   32584  Varies with device   1,000,000+  Free     0
# 1393      4.0    2490                3.8M     500,000+  Free     0
# 524       4.4   35206                7.2M   1,000,000+  Free     0
# 3257      4.6  315585                8.5M  10,000,000+  Free     0
# 1426      4.3   13724  Varies with device   1,000,000+  Free     0
# 4691      4.1    2399                 42M     100,000+  Free     0
#
#       Content Rating            Genres
# 10198           Teen            Social
# 191         Everyone          Business
# 1393    Everyone 10+  Health & Fitness
# 524         Everyone            Dating
# 3257        Everyone             Tools
# 1426        Everyone  Health & Fitness
# 4691      Mature 17+            Action

# %%
apps.duplicated().value_counts()
# Out:
# False    10356
# True       485
# dtype: int64

# %%
apps.drop_duplicates(inplace=True)

# %%
#apps.dropna(how ='any', inplace = True)

# %% [markdown]
# Vérifier combien de valeurs manquantes :

# %%
apps.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# dtype: int64

# %%
#apps.dropna()
apps.drop_duplicates(subset='App', inplace=True)
#df = df[df['Android Ver'] != 'NaN']
#df = df[df['Installs'] != 'Free']
#df = df[df['Installs'] != 'Paid']

# %%
print(apps.shape)
# Out:
# (9660, 10)

# %%
apps.describe()
# Out:
#             Rating
# count  8197.000000
# mean      4.175052
# std       0.561026
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# ## Applications gratuites / payantes

# %%
typeApp = apps.groupby(['Type'], as_index=False)["App"].count()

pourcentageType = typeApp.loc[:, 'App']
labels = typeApp.loc[:, 'Type']

plt.pie(pourcentageType)
plt.legend(labels, bbox_to_anchor=(0.85,1.025), loc="upper left")
plt.show()

# %%
types = apps["Type"].unique()
print(types)
# Out:
# ['Free' 'Paid' nan '0']

# %%
#apps = apps.loc[apps["Type"] != "0"]
apps.dropna(how ='any', inplace = True)

# %%
types = apps["Type"].unique()
types
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
typeApp = apps.groupby(['Type'], as_index=False)["App"].count()

pourcentageType = typeApp.loc[:, 'App']
labels = typeApp.loc[:, 'Type']

plt.pie(pourcentageType, autopct='%.1f%%')
plt.legend(labels, bbox_to_anchor=(0.95,1.025), loc="upper left")
plt.title('Pourcentage applications gratuites/payantes',color='r')
plt.show()

# %% [markdown]
# ## Catégories

# %%
categories = apps["Category"].unique()
print(categories)
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']

# %%
categ = apps.groupby(['Category'], as_index=False)['App'].count()

pourcentage = categ.loc[:, 'App']
labels = categ.loc[:, 'Category']

plt.pie(pourcentage)
plt.legend(labels, bbox_to_anchor=(1.5,1.025), loc="upper left")
plt.title('Catégories')
plt.show()
categ
# Out:
#                Category   App
# 0        ART_AND_DESIGN    61
# 1     AUTO_AND_VEHICLES    73
# 2                BEAUTY    42
# 3   BOOKS_AND_REFERENCE   169
# 4              BUSINESS   263
# 5                COMICS    54
# 6         COMMUNICATION   256
# 7                DATING   134
# 8             EDUCATION   118
# 9         ENTERTAINMENT   102
# 10               EVENTS    45
# 11               FAMILY  1608
# 12              FINANCE   302
# 13       FOOD_AND_DRINK    94
# 14                 GAME   912
# 15   HEALTH_AND_FITNESS   244
# 16       HOUSE_AND_HOME    62
# 17   LIBRARIES_AND_DEMO    64
# 18            LIFESTYLE   301
# 19  MAPS_AND_NAVIGATION   118
# 20              MEDICAL   290
# 21   NEWS_AND_MAGAZINES   204
# 22            PARENTING    50
# 23      PERSONALIZATION   298
# 24          PHOTOGRAPHY   263
# 25         PRODUCTIVITY   301
# 26             SHOPPING   180
# 27               SOCIAL   203
# 28               SPORTS   260
# 29                TOOLS   718
# 30     TRAVEL_AND_LOCAL   187
# 31        VIDEO_PLAYERS   148
# 32              WEATHER    72

# %% [markdown]
# ### Réduction des Catégories

# %% [markdown]
# | Catégories Principales | Sous-Catégories |
# | :----: | :---- |
# | Lifestyle | BEAUTY,  FOOD_AND_DRINK, HEALTH_AND_FITNESS, LIFESTYLE, HOUSE_AND_HOME, ART_AND_DESIGN, AUTO_AND_VEHICLES, TRAVEL_AND_LOCAL |
# | Social Media | DATING,  COMMUNICATION, SOCIAL, FAMILY |
# | Games/Entertainment | COMICS,  GAME, ENTERTAINMENT, SPORTS, EVENTS |
# | Productivity/Business | PRODUCTIVITY,  EDUCATION, BUSINESS, FINANCE |
# | News/Information Outlets | NEWS_AND_MAGAZINES, WEATHER, LIBRARIES_AND_DEMO, BOOKS_AND_REFERENCE |
# | Utility | MAPS_AND_NAVIGATION, SHOPPING, VIDEO_PLAYERS, TOOLS, PHOTOGRAPHY,  PERSONALIZATION |

# %%
LIFE = "Lifestyle"
SM = "Social Media"
FUN = "Games/Entertainment"
PROD = "Productivity/Business"
NEWS = "News/Information Outlets"
UTIL = "Utility"

listLIFE = ['BEAUTY',  'FOOD_AND_DRINK',
            'HEALTH_AND_FITNESS', 'LIFESTYLE', 
            'HOUSE_AND_HOME', 'ART_AND_DESIGN', 
            'AUTO_AND_VEHICLES', 'TRAVEL_AND_LOCAL']
listSM = ['DATING',  'COMMUNICATION', 'SOCIAL', 'FAMILY']
listFUN = ['COMICS',  'GAME', 'ENTERTAINMENT', 
           'SPORTS', 'EVENTS']
listPROD = ['PRODUCTIVITY',  'EDUCATION', 'BUSINESS', 'FINANCE']
listNEWS = ['NEWS_AND_MAGAZINES', 'WEATHER', 
            'LIBRARIES_AND_DEMO', 'BOOKS_AND_REFERENCE']
listUTIL = ['MAPS_AND_NAVIGATION', 'SHOPPING', 
            'VIDEO_PLAYERS', 'TOOLS', 'PHOTOGRAPHY',  
            'PERSONALIZATION']

apps.loc[apps['Category'].isin(listSM), 'Main Category'] = SM
apps.loc[apps['Category'].isin(listLIFE), 'Main Category'] = LIFE
apps.loc[apps['Category'].isin(listFUN), 'Main Category'] = FUN
apps.loc[apps['Category'].isin(listPROD), 'Main Category'] = PROD
apps.loc[apps['Category'].isin(listNEWS), 'Main Category'] = NEWS
apps.loc[apps['Category'].isin(listUTIL), 'Main Category'] = UTIL

# %%
categN = apps.groupby(['Main Category'], as_index=False)['App'].count()

pourcentage = categN.loc[:, 'App']
labels = categN.loc[:, 'Main Category']

plt.pie(pourcentage, autopct='%.1f%%', radius=1.5)
plt.legend(labels, bbox_to_anchor=(1.2, 1.025), loc="upper left", title = "Catégories principales:")
plt.title('Catégories principales', pad=32)
fig = plt.gcf()
fig.set_size_inches(5,5)
plt.show()

# %%
mainCategories = apps["Main Category"].unique()
print(mainCategories)
# Out:
# ['Lifestyle' 'News/Information Outlets' 'Productivity/Business'
#  'Games/Entertainment' 'Social Media' nan 'Utility']

# %%
apps.dropna()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10834     4.0       7                2.6M         500+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres             Main Category
# 0           Everyone               Art & Design                 Lifestyle
# 1           Everyone  Art & Design;Pretend Play                 Lifestyle
# 2           Everyone               Art & Design                 Lifestyle
# 3               Teen               Art & Design                 Lifestyle
# 4           Everyone    Art & Design;Creativity                 Lifestyle
# ...              ...                        ...                       ...
# 10834       Everyone                  Education              Social Media
# 10836       Everyone                  Education              Social Media
# 10837       Everyone                  Education              Social Media
# 10839     Mature 17+          Books & Reference  News/Information Outlets
# 10840       Everyone                  Lifestyle                 Lifestyle
#
# [7856 rows x 11 columns]

# %% [markdown]
# ---

# %% [markdown]
# - Les 10 meilleures applications dans chaque catégorie

# %%
# La somme des évaluations
q2 = apps.groupby(['Main Category'],as_index=False)['Rating'].sum().sort_values('Rating')


# Bar chart
plt.barh(q2['Main Category'], q2['Rating'])
plt.title("Total des évaluations de chaque catégorie")
plt.show()

# %%
apps['Installs'].value_counts()
# Out:
# 1,000,000+        1415
# 100,000+          1094
# 10,000+            987
# 10,000,000+        937
# 1,000+             697
# 5,000,000+         607
# 500,000+           504
# 50,000+            457
# 5,000+             425
# 100+               303
# 50,000,000+        202
# 500+               199
# 100,000,000+       188
# 10+                 69
# 50+                 56
# 500,000,000+        24
# 1,000,000,000+      20
# 5+                   9
# 1+                   3
# Name: Installs, dtype: int64

# %%
apps.Installs = apps.Installs.apply(lambda x : x.strip('+').replace(',', ''))

apps.drop(apps[apps['Installs'] == "Free"].index, inplace = True)

# %%
apps.Installs=pd.to_numeric(apps.Installs)
apps['Installs'] = apps['Installs'].astype(int)
res = apps.groupby('App')['Installs'].sum().reset_index()
final_result = res.sort_values(by = 'Installs', ascending = False).head(10)

# %%
plt.bar("App", "Installs", data = final_result)
plt.xlabel("Apps")
plt.xticks(rotation = 90)
plt.ylabel("Nombre d'installations")
plt.title("Top 10 applications par nombre d'installations")
plt.show()

# %% [markdown]
# ### - Meilleur Application dans chaque catégorie

# %%
apps.Reviews = pd.to_numeric(apps.Reviews)

# %%
result = apps.loc[apps.groupby(['Main Category']).Rating.agg('idxmax').reset_index(drop=True)]

# %%
result
# Out:
#                                                    App            Category  \
# 329                       Hojiboy Tojiboyev Life Hacks              COMICS
# 5064  Tafsiir Quraan MP3 Af Soomaali Quraanka Kariimka           LIFESTYLE
# 1547                                      Eternal life  LIBRARIES_AND_DEMO
# 5125                             Ag Valley Cooperative            BUSINESS
# 612                      American Girls Mobile Numbers              DATING
# 3957                                      ADS-B Driver               TOOLS
#
#       Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# 329      5.0       15   37M      1000  Free      0       Everyone
# 5064     5.0        7  3.4M      1000  Free      0       Everyone
# 1547     5.0       26  2.5M      1000  Free      0       Everyone
# 5125     5.0        6   74M       500  Free      0       Everyone
# 612      5.0        5  4.4M      1000  Free      0     Mature 17+
# 3957     5.0        2  6.3M       100  Paid  $1.99       Everyone
#
#                 Genres             Main Category
# 329             Comics       Games/Entertainment
# 5064         Lifestyle                 Lifestyle
# 1547  Libraries & Demo  News/Information Outlets
# 5125          Business     Productivity/Business
# 612             Dating              Social Media
# 3957             Tools                   Utility

# %%
apps.Reviews = pd.to_numeric(apps.Reviews)
apps.Rating
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10834    4.0
# 10836    4.5
# 10837    5.0
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 8196, dtype: float64

# %%
apps.Rating.dtypes
# Out:
# dtype('float64')

# %%
apps.Reviews.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Rating/Reviews

# %%
apps_new = apps
apps_new["Rating/Reviews"] = apps.Rating/apps.Reviews

# %%
ratio = apps_new.loc[apps.groupby(['Main Category'])['Rating/Reviews'].agg('idxmin').reset_index(drop=True)]

# %%
ratio
# Out:
#                                           App            Category  Rating  \
# 1670                           Clash of Clans                GAME     4.6
# 3117                Maps - Navigate & Explore    TRAVEL_AND_LOCAL     4.3
# 3739                                  Twitter  NEWS_AND_MAGAZINES     4.3
# 699            Duolingo: Learn Languages Free           EDUCATION     4.7
# 2544                                 Facebook              SOCIAL     4.1
# 4005  Clean Master- Space Cleaner & Antivirus               TOOLS     4.7
#
#        Reviews                Size    Installs  Type Price Content Rating  \
# 1670  44891723                 98M   100000000  Free     0   Everyone 10+
# 3117   9235155  Varies with device  1000000000  Free     0       Everyone
# 3739  11667403  Varies with device   500000000  Free     0     Mature 17+
# 699    6289924  Varies with device   100000000  Free     0       Everyone
# 2544  78158306  Varies with device  1000000000  Free     0           Teen
# 4005  42916526  Varies with device   500000000  Free     0       Everyone
#
#                    Genres             Main Category  Rating/Reviews
# 1670             Strategy       Games/Entertainment    1.024688e-07
# 3117       Travel & Local                 Lifestyle    4.656121e-07
# 3739     News & Magazines  News/Information Outlets    3.685482e-07
# 699   Education;Education     Productivity/Business    7.472268e-07
# 2544               Social              Social Media    5.245764e-08
# 4005                Tools                   Utility    1.095149e-07

# %%
#test Rating/Installs

# %%
apps_installs = apps
apps_installs["Rating/Installs"] = apps.Rating/apps.Installs

# %%
ratio = apps_installs.loc[apps.groupby(['Main Category'])['Rating/Installs'].agg('idxmin').reset_index(drop=True)]

# %%
ratio
# Out:
#                                            App             Category  Rating  \
# 865                          Google Play Games        ENTERTAINMENT     4.3
# 3127                        Google Street View     TRAVEL_AND_LOCAL     4.2
# 152                          Google Play Books  BOOKS_AND_REFERENCE     3.9
# 3454                              Google Drive         PRODUCTIVITY     4.4
# 335   Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 3687                   Google Play Movies & TV        VIDEO_PLAYERS     3.7
#
#        Reviews                Size    Installs  Type Price Content Rating  \
# 865    7165362  Varies with device  1000000000  Free     0           Teen
# 3127   2129689  Varies with device  1000000000  Free     0       Everyone
# 152    1433233  Varies with device  1000000000  Free     0           Teen
# 3454   2731171  Varies with device  1000000000  Free     0       Everyone
# 335   56642847  Varies with device  1000000000  Free     0       Everyone
# 3687    906384  Varies with device  1000000000  Free     0           Teen
#
#                        Genres             Main Category  Rating/Reviews  \
# 865             Entertainment       Games/Entertainment    6.001092e-07
# 3127           Travel & Local                 Lifestyle    1.972119e-06
# 152         Books & Reference  News/Information Outlets    2.721121e-06
# 3454             Productivity     Productivity/Business    1.611031e-06
# 335             Communication              Social Media    7.061792e-08
# 3687  Video Players & Editors                   Utility    4.082155e-06
#
#       Rating/Installs
# 865      4.300000e-09
# 3127     4.200000e-09
# 152      3.900000e-09
# 3454     4.400000e-09
# 335      4.000000e-09
# 3687     3.700000e-09
